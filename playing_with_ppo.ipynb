# %%
import gym
import inventory
import numpy as np


from stable_baselines3 import PPO
from stable_baselines3.ppo import MlpPolicy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy


env = make_vec_env('inventory-v0', n_envs=4)


model = PPO(MlpPolicy, env, verbose=1, n_steps=512, gamma = 1)
model.learn(total_timesteps=1000000)

model.save("inv_1")
env = gym.make('inventory-v0')
n_episodes = 1
res_mean, res_std = evaluate_policy(model, env, n_eval_episodes=n_episodes)
print(-res_mean,'+/-',1.96*res_std/np.sqrt(n_episodes))

#env = CrissCross(load = 0.5)#gym.make('criss_cross-v0')
# n_steps = 20000
# av_reward = np.zeros(n_steps)
# av_r = 0.
# env.reset()
# for i in range(n_steps):
#     # Random action
#     k = 0
#     done = False
#     env.reset()
#     av_r = 0.
#     while not done:
#         action = env.action_space.sample()
#         obs, reward, done, info = env.step(action)
#         av_r = reward +  av_r
#         k = k + 1
#
#     av_reward[i]=av_r
#
#
# print(np.mean(av_reward),'+-',1.96*np.std(av_reward)/np.sqrt(n_steps))
# Out:
# Using cuda device
# ---------------------------------
# | time/              |          |
# |    fps             | 3269     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# | train/             |          |
# |    learning_rate   | 0.0003   |
# ---------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1307         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0036019573 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -31.1        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0237      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00334     |
# |    std                  | 0.966        |
# |    value_loss           | 0.000527     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1102         |
# |    iterations           | 3            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0044935253 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -30.4        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00402     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00231     |
# |    std                  | 0.982        |
# |    value_loss           | 8.75e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1010        |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.004005924 |
# |    clip_fraction        | 0.0164      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | -18.8       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0125      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0039     |
# |    std                  | 0.963       |
# |    value_loss           | 6.54e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 970          |
# |    iterations           | 5            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0012692232 |
# |    clip_fraction        | 0.0295       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -20.5        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00468     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00477     |
# |    std                  | 0.953        |
# |    value_loss           | 5.85e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 946          |
# |    iterations           | 6            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0062808925 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -1.29        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00892     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00393     |
# |    std                  | 0.945        |
# |    value_loss           | 1.61e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 929          |
# |    iterations           | 7            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0020070418 |
# |    clip_fraction        | 0.0085       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -7.9         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00303      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000977    |
# |    std                  | 0.962        |
# |    value_loss           | 6.51e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 911          |
# |    iterations           | 8            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0064813234 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -2.51        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0131      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00337     |
# |    std                  | 0.955        |
# |    value_loss           | 1.4e-06      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 902          |
# |    iterations           | 9            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0016788852 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -1.04        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0048      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00199     |
# |    std                  | 0.94         |
# |    value_loss           | 4.72e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 894         |
# |    iterations           | 10          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.006165128 |
# |    clip_fraction        | 0.0427      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -1.69       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00254    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00536    |
# |    std                  | 0.926       |
# |    value_loss           | 1.54e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 888          |
# |    iterations           | 11           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0044611925 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -1.38        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00851      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00425     |
# |    std                  | 0.933        |
# |    value_loss           | 5.22e-07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 883           |
# |    iterations           | 12            |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | -9.394018e-06 |
# |    clip_fraction        | 0.0249        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | -0.302        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00693      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.00472      |
# |    std                  | 0.918         |
# |    value_loss           | 4.3e-07       |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 880         |
# |    iterations           | 13          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008505007 |
# |    clip_fraction        | 0.0236      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.88       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00719     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00249    |
# |    std                  | 0.916       |
# |    value_loss           | 3.51e-07    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 875         |
# |    iterations           | 14          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.002740851 |
# |    clip_fraction        | 0.01        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.484      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00492    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0015     |
# |    std                  | 0.893       |
# |    value_loss           | 3.87e-07    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 871         |
# |    iterations           | 15          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008927486 |
# |    clip_fraction        | 0.0299      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -0.536      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0142     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00544    |
# |    std                  | 0.865       |
# |    value_loss           | 1.17e-06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 869         |
# |    iterations           | 16          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.005607093 |
# |    clip_fraction        | 0.0487      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -0.393      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0149     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00618    |
# |    std                  | 0.85        |
# |    value_loss           | 3.54e-07    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 864         |
# |    iterations           | 17          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.003304632 |
# |    clip_fraction        | 0.013       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | -0.196      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00319     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00112    |
# |    std                  | 0.844       |
# |    value_loss           | 2.86e-07    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 861         |
# |    iterations           | 18          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004037898 |
# |    clip_fraction        | 0.0112      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | -0.383      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0048      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.000914   |
# |    std                  | 0.848       |
# |    value_loss           | 4.68e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 860          |
# |    iterations           | 19           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0032546408 |
# |    clip_fraction        | 0.0084       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | -0.179       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00519      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00148     |
# |    std                  | 0.83         |
# |    value_loss           | 3.27e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.959       |
# | time/                   |              |
# |    fps                  | 856          |
# |    iterations           | 20           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0039320523 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | -0.168       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.017        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000778    |
# |    std                  | 0.825        |
# |    value_loss           | 4.35e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | -0.959      |
# | time/                   |             |
# |    fps                  | 856         |
# |    iterations           | 21          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.001786335 |
# |    clip_fraction        | 0.0159      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | -0.00014    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00374     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00101    |
# |    std                  | 0.805       |
# |    value_loss           | 0.00012     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.959       |
# | time/                   |              |
# |    fps                  | 854          |
# |    iterations           | 22           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0018991175 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | -33.9        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00302     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00111     |
# |    std                  | 0.8          |
# |    value_loss           | 8.61e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.959       |
# | time/                   |              |
# |    fps                  | 852          |
# |    iterations           | 23           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0032646484 |
# |    clip_fraction        | 0.0473       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | -0.963       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0055      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00424     |
# |    std                  | 0.803        |
# |    value_loss           | 2.43e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | -0.959      |
# | time/                   |             |
# |    fps                  | 850         |
# |    iterations           | 24          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004522737 |
# |    clip_fraction        | 0.0261      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | -0.121      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0085     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00277    |
# |    std                  | 0.8         |
# |    value_loss           | 2.61e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.959       |
# | time/                   |              |
# |    fps                  | 850          |
# |    iterations           | 25           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0024853253 |
# |    clip_fraction        | 0.0294       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | -0.149       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0132      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0027      |
# |    std                  | 0.793        |
# |    value_loss           | 2.47e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | -0.959      |
# | time/                   |             |
# |    fps                  | 849         |
# |    iterations           | 26          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.004229305 |
# |    clip_fraction        | 0.00767     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | -0.334      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00482     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.000416   |
# |    std                  | 0.795       |
# |    value_loss           | 2.81e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.959       |
# | time/                   |              |
# |    fps                  | 848          |
# |    iterations           | 27           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0012638138 |
# |    clip_fraction        | 0.00581      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | -0.231       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0158      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00105     |
# |    std                  | 0.776        |
# |    value_loss           | 2.77e-07     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+04      |
# |    ep_rew_mean          | -0.959     |
# | time/                   |            |
# |    fps                  | 848        |
# |    iterations           | 28         |
# |    time_elapsed         | 67         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.00460108 |
# |    clip_fraction        | 0.032      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.16      |
# |    explained_variance   | -0.105     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0199     |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.00299   |
# |    std                  | 0.766      |
# |    value_loss           | 3.56e-07   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.959       |
# | time/                   |              |
# |    fps                  | 848          |
# |    iterations           | 29           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0011032684 |
# |    clip_fraction        | 0.00249      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | -0.185       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00318      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -7.77e-05    |
# |    std                  | 0.758        |
# |    value_loss           | 2.11e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.959       |
# | time/                   |              |
# |    fps                  | 847          |
# |    iterations           | 30           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0041171527 |
# |    clip_fraction        | 0.00972      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | -0.173       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000675     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00133     |
# |    std                  | 0.752        |
# |    value_loss           | 2.19e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.959       |
# | time/                   |              |
# |    fps                  | 845          |
# |    iterations           | 31           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0017860096 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | -0.109       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0092      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00102     |
# |    std                  | 0.754        |
# |    value_loss           | 2.56e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.959       |
# | time/                   |              |
# |    fps                  | 844          |
# |    iterations           | 32           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0055833897 |
# |    clip_fraction        | 0.0356       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | -0.229       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0162      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00302     |
# |    std                  | 0.763        |
# |    value_loss           | 3.05e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | -0.959      |
# | time/                   |             |
# |    fps                  | 843         |
# |    iterations           | 33          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.001611915 |
# |    clip_fraction        | 0.0224      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | -0.122      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00504    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00188    |
# |    std                  | 0.744       |
# |    value_loss           | 3.66e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | -0.959      |
# | time/                   |             |
# |    fps                  | 842         |
# |    iterations           | 34          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.003394132 |
# |    clip_fraction        | 0.0378      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | -0.456      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0293     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00376    |
# |    std                  | 0.735       |
# |    value_loss           | 4.6e-07     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.959       |
# | time/                   |              |
# |    fps                  | 841          |
# |    iterations           | 35           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0036883233 |
# |    clip_fraction        | 0.0319       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | -0.121       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0163       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0028      |
# |    std                  | 0.733        |
# |    value_loss           | 3e-07        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.959       |
# | time/                   |              |
# |    fps                  | 841          |
# |    iterations           | 36           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0058457507 |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.291       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00789      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00179     |
# |    std                  | 0.725        |
# |    value_loss           | 2.88e-07     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+04      |
# |    ep_rew_mean          | -0.959     |
# | time/                   |            |
# |    fps                  | 840        |
# |    iterations           | 37         |
# |    time_elapsed         | 90         |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.00962793 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | -0.113     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0174    |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0106    |
# |    std                  | 0.719      |
# |    value_loss           | 5.26e-07   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | -0.959      |
# | time/                   |             |
# |    fps                  | 839         |
# |    iterations           | 38          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.006614776 |
# |    clip_fraction        | 0.0301      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | -0.159      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00947    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00214    |
# |    std                  | 0.725       |
# |    value_loss           | 3.03e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | -0.959      |
# | time/                   |             |
# |    fps                  | 838         |
# |    iterations           | 39          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.010667507 |
# |    clip_fraction        | 0.0666      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.731      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00891     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0057     |
# |    std                  | 0.718       |
# |    value_loss           | 4.63e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.919       |
# | time/                   |              |
# |    fps                  | 838          |
# |    iterations           | 40           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0060489587 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -1.15        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00225      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00127     |
# |    std                  | 0.706        |
# |    value_loss           | 3.89e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.919       |
# | time/                   |              |
# |    fps                  | 838          |
# |    iterations           | 41           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0008295252 |
# |    clip_fraction        | 0.0555       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -0.000125    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00617      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00254     |
# |    std                  | 0.704        |
# |    value_loss           | 0.000225     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+04      |
# |    ep_rew_mean          | -0.919     |
# | time/                   |            |
# |    fps                  | 838        |
# |    iterations           | 42         |
# |    time_elapsed         | 102        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.00356554 |
# |    clip_fraction        | 0.0359     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | -26.1      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.023     |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.00531   |
# |    std                  | 0.701      |
# |    value_loss           | 1.33e-06   |
# ----------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 1e+04          |
# |    ep_rew_mean          | -0.919         |
# | time/                   |                |
# |    fps                  | 837            |
# |    iterations           | 43             |
# |    time_elapsed         | 105            |
# |    total_timesteps      | 88064          |
# | train/                  |                |
# |    approx_kl            | -0.00018775836 |
# |    clip_fraction        | 0.0267         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.06          |
# |    explained_variance   | -1.24          |
# |    learning_rate        | 0.0003         |
# |    loss                 | -0.000169      |
# |    n_updates            | 420            |
# |    policy_gradient_loss | -0.00211       |
# |    std                  | 0.69           |
# |    value_loss           | 1.48e-07       |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.919       |
# | time/                   |              |
# |    fps                  | 837          |
# |    iterations           | 44           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0039299056 |
# |    clip_fraction        | 0.0395       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.171       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00171     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00327     |
# |    std                  | 0.689        |
# |    value_loss           | 2.08e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.919       |
# | time/                   |              |
# |    fps                  | 836          |
# |    iterations           | 45           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0019990331 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.178       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0169      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00184     |
# |    std                  | 0.689        |
# |    value_loss           | 2.58e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.919       |
# | time/                   |              |
# |    fps                  | 836          |
# |    iterations           | 46           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0032740547 |
# |    clip_fraction        | 0.0192       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.252       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0128      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00135     |
# |    std                  | 0.687        |
# |    value_loss           | 2.76e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.919       |
# | time/                   |              |
# |    fps                  | 836          |
# |    iterations           | 47           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0032474534 |
# |    clip_fraction        | 0.0291       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | -0.412       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00128     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00212     |
# |    std                  | 0.684        |
# |    value_loss           | 2.81e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.919       |
# | time/                   |              |
# |    fps                  | 836          |
# |    iterations           | 48           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0039959555 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | -0.137       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00872     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00342     |
# |    std                  | 0.663        |
# |    value_loss           | 3.24e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.919       |
# | time/                   |              |
# |    fps                  | 836          |
# |    iterations           | 49           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0030450495 |
# |    clip_fraction        | 0.0217       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | -0.154       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0115       |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000859    |
# |    std                  | 0.656        |
# |    value_loss           | 5.88e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.919       |
# | time/                   |              |
# |    fps                  | 836          |
# |    iterations           | 50           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0038446407 |
# |    clip_fraction        | 0.0288       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.994       |
# |    explained_variance   | -0.324       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00999     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00222     |
# |    std                  | 0.653        |
# |    value_loss           | 2.9e-07      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.919       |
# | time/                   |              |
# |    fps                  | 836          |
# |    iterations           | 51           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0032399215 |
# |    clip_fraction        | 0.0144       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.983       |
# |    explained_variance   | -0.241       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0192      |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.000683    |
# |    std                  | 0.643        |
# |    value_loss           | 3.05e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.919       |
# | time/                   |              |
# |    fps                  | 835          |
# |    iterations           | 52           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0005158928 |
# |    clip_fraction        | 0.00562      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.976       |
# |    explained_variance   | -0.163       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000861     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | 0.000151     |
# |    std                  | 0.641        |
# |    value_loss           | 5.09e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.919       |
# | time/                   |              |
# |    fps                  | 834          |
# |    iterations           | 53           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0032860595 |
# |    clip_fraction        | 0.0432       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.977       |
# |    explained_variance   | -0.617       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00655     |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00304     |
# |    std                  | 0.643        |
# |    value_loss           | 3.82e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.919       |
# | time/                   |              |
# |    fps                  | 834          |
# |    iterations           | 54           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0019461008 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.973       |
# |    explained_variance   | -0.929       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000664    |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00029     |
# |    std                  | 0.638        |
# |    value_loss           | 5.61e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.919       |
# | time/                   |              |
# ...
# |    iterations           | 473         |
# |    time_elapsed         | 1196        |
# |    total_timesteps      | 968704      |
# | train/                  |             |
# |    approx_kl            | 0.012545655 |
# |    clip_fraction        | 0.0792      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.56        |
# |    explained_variance   | -0.478      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0172     |
# |    n_updates            | 4720        |
# |    policy_gradient_loss | 0.00226     |
# |    std                  | 0.0509      |
# |    value_loss           | 2.08e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | -0.821      |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 474         |
# |    time_elapsed         | 1198        |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.011121795 |
# |    clip_fraction        | 0.0834      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.56        |
# |    explained_variance   | -0.716      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0139      |
# |    n_updates            | 4730        |
# |    policy_gradient_loss | 0.00143     |
# |    std                  | 0.0509      |
# |    value_loss           | 2.06e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | -0.821      |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 475         |
# |    time_elapsed         | 1201        |
# |    total_timesteps      | 972800      |
# | train/                  |             |
# |    approx_kl            | 0.007554391 |
# |    clip_fraction        | 0.0981      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.56        |
# |    explained_variance   | -0.769      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0209     |
# |    n_updates            | 4740        |
# |    policy_gradient_loss | 0.00282     |
# |    std                  | 0.051       |
# |    value_loss           | 2.05e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | -0.821      |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 476         |
# |    time_elapsed         | 1203        |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.000522217 |
# |    clip_fraction        | 0.0785      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.56        |
# |    explained_variance   | -0.397      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00801     |
# |    n_updates            | 4750        |
# |    policy_gradient_loss | 0.00232     |
# |    std                  | 0.0512      |
# |    value_loss           | 2.37e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | -0.821      |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 477         |
# |    time_elapsed         | 1206        |
# |    total_timesteps      | 976896      |
# | train/                  |             |
# |    approx_kl            | 0.008468952 |
# |    clip_fraction        | 0.0708      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.55        |
# |    explained_variance   | -0.446      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0019      |
# |    n_updates            | 4760        |
# |    policy_gradient_loss | 0.00181     |
# |    std                  | 0.052       |
# |    value_loss           | 2.35e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | -0.821      |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 478         |
# |    time_elapsed         | 1208        |
# |    total_timesteps      | 978944      |
# | train/                  |             |
# |    approx_kl            | 0.006462573 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.55        |
# |    explained_variance   | -0.534      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00559    |
# |    n_updates            | 4770        |
# |    policy_gradient_loss | 0.00186     |
# |    std                  | 0.0511      |
# |    value_loss           | 2.22e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | -0.821      |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 479         |
# |    time_elapsed         | 1211        |
# |    total_timesteps      | 980992      |
# | train/                  |             |
# |    approx_kl            | 0.010612223 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.56        |
# |    explained_variance   | -0.555      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00376     |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | 0.00407     |
# |    std                  | 0.0502      |
# |    value_loss           | 5.72e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.821       |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 480          |
# |    time_elapsed         | 1213         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0026887737 |
# |    clip_fraction        | 0.0769       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.57         |
# |    explained_variance   | -0.514       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000373    |
# |    n_updates            | 4790         |
# |    policy_gradient_loss | 0.00153      |
# |    std                  | 0.0503       |
# |    value_loss           | 2.32e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.821       |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 481          |
# |    time_elapsed         | 1216         |
# |    total_timesteps      | 985088       |
# | train/                  |              |
# |    approx_kl            | 0.0036783982 |
# |    clip_fraction        | 0.0716       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.57         |
# |    explained_variance   | -0.574       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0265       |
# |    n_updates            | 4800         |
# |    policy_gradient_loss | 0.00185      |
# |    std                  | 0.0504       |
# |    value_loss           | 2.09e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.821       |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 482          |
# |    time_elapsed         | 1218         |
# |    total_timesteps      | 987136       |
# | train/                  |              |
# |    approx_kl            | 0.0045276154 |
# |    clip_fraction        | 0.0866       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.57         |
# |    explained_variance   | -0.529       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0107       |
# |    n_updates            | 4810         |
# |    policy_gradient_loss | 0.0023       |
# |    std                  | 0.0499       |
# |    value_loss           | 2.82e-07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.821       |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 483          |
# |    time_elapsed         | 1221         |
# |    total_timesteps      | 989184       |
# | train/                  |              |
# |    approx_kl            | 0.0067148185 |
# |    clip_fraction        | 0.0932       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.59         |
# |    explained_variance   | -0.679       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0313      |
# |    n_updates            | 4820         |
# |    policy_gradient_loss | 0.00275      |
# |    std                  | 0.0492       |
# |    value_loss           | 2.19e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | -0.821      |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 484         |
# |    time_elapsed         | 1223        |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.005406048 |
# |    clip_fraction        | 0.0746      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.58        |
# |    explained_variance   | -0.558      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00734    |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | 0.00129     |
# |    std                  | 0.0498      |
# |    value_loss           | 6.86e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.821       |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 485          |
# |    time_elapsed         | 1226         |
# |    total_timesteps      | 993280       |
# | train/                  |              |
# |    approx_kl            | 0.0011536073 |
# |    clip_fraction        | 0.074        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.59         |
# |    explained_variance   | -0.385       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00985      |
# |    n_updates            | 4840         |
# |    policy_gradient_loss | 0.00112      |
# |    std                  | 0.0489       |
# |    value_loss           | 2.46e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | -0.821      |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 486         |
# |    time_elapsed         | 1229        |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.007378407 |
# |    clip_fraction        | 0.0848      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.6         |
# |    explained_variance   | -0.532      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0135      |
# |    n_updates            | 4850        |
# |    policy_gradient_loss | 0.00221     |
# |    std                  | 0.0489      |
# |    value_loss           | 2.51e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | -0.821      |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 487         |
# |    time_elapsed         | 1231        |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.003977452 |
# |    clip_fraction        | 0.0696      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.6         |
# |    explained_variance   | -0.568      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.014       |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | 0.00248     |
# |    std                  | 0.0489      |
# |    value_loss           | 2.4e-07     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | -0.821      |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 488         |
# |    time_elapsed         | 1234        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.014413067 |
# |    clip_fraction        | 0.0898      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.6         |
# |    explained_variance   | -0.528      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0121      |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | 0.00355     |
# |    std                  | 0.049       |
# |    value_loss           | 2.86e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | -0.82        |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 489          |
# |    time_elapsed         | 1236         |
# |    total_timesteps      | 1001472      |
# | train/                  |              |
# |    approx_kl            | 0.0051450077 |
# |    clip_fraction        | 0.0882       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.6          |
# |    explained_variance   | -0.448       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00221      |
# |    n_updates            | 4880         |
# |    policy_gradient_loss | 0.0026       |
# |    std                  | 0.0489       |
# |    value_loss           | 2.44e-07     |
# ------------------------------------------
# C:\Users\fordm\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# 0.7818297703891433 +/- 0.0
